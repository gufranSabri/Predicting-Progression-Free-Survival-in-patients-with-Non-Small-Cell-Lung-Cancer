# %%
import pandas as pd
import os

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df_t = pd.read_parquet("/Users/gufran/Desktop/PfsPredictionLungCancer/radiology/radiomics_features/LUNG_RADIOMICS_spacing1.0_MirpOn_Window1350.250_allImageTypes_bw20.parquet", engine='pyarrow').reset_index()
df_v = pd.read_parquet("/Users/gufran/Desktop/PfsPredictionLungCancer/radiology/radiomics_features/LUNG_RADIOMICS_spacing1.0_MirpOn_Window1350.250_allImageTypes_bw20_VALIDATION.parquet", engine='pyarrow').reset_index()
df_t = df_t.rename(columns={'main_index': 'dmp_pt_id'})
df_v = df_v.rename(columns={'main_index': 'radiology_accession_number'})

df_t.drop(["job_tag"], axis=1, inplace=True)
df_v.drop(["job_tag"], axis=1, inplace=True)

df_v['radiology_accession_number'] = pd.to_numeric(df_v['radiology_accession_number'], errors='coerce').astype(object)

df_t.shape, df_v.shape
# Out:
# ((3996, 1690), (1176, 1690))

# %%
df_t.head()
# Out:
#    dmp_pt_id  lesion_index  original_shape_Elongation  \
# 0  P-0000239             1                   0.609991
# 1  P-0000239             1                   0.602659
# 2  P-0000239             1                   0.626577
# 3  P-0000239             1                   0.685398
# 4  P-0000239             1                   0.633165
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.547450                       17.435125
# 1                 0.557320                       17.530776
# 2                 0.535450                       17.343918
# 3                 0.640327                       18.342757
# 4                 0.559689                       17.613374
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       31.847914                               33.970576
# 1                       31.455496                               32.557641
# 2                       32.391268                               37.802116
# 3                       28.645906                               34.132096
# 4                       31.469915                               34.132096
#
#    original_shape_Maximum2DDiameterRow  original_shape_Maximum2DDiameterSlice  \
# 0                            33.105891                              25.553865
# 1                            32.695565                              24.351591
# 2                            38.897301                              26.400758
# 3                            38.897301                              28.844410
# 4                            38.897301                              28.844410
#
#    original_shape_Maximum3DDiameter  ...  \
# 0                         39.962482  ...
# 1                         39.089641  ...
# 2                         41.448764  ...
# 3                         39.344631  ...
# 4                         39.344631  ...
#
#    wavelet-LLL_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       1046.802692
# 1                                        646.730034
# 2                                        904.065174
# 3                                        947.556576
# 4                                       2475.982809
#
#    wavelet-LLL_glszm_SmallAreaLowGrayLevelEmphasis  \
# 0                                         0.001751
# 1                                         0.003363
# 2                                         0.003693
# 3                                         0.001619
# 4                                         0.001237
#
#    wavelet-LLL_glszm_ZoneEntropy  wavelet-LLL_glszm_ZonePercentage  \
# 0                       6.371523                          0.158582
# 1                       6.101283                          0.159459
# 2                       6.650200                          0.151809
# 3                       6.511064                          0.108050
# 4                       6.611130                          0.177028
#
#    wavelet-LLL_glszm_ZoneVariance  wavelet-LLL_ngtdm_Busyness  \
# 0                     3270.745421                    0.128236
# 1                     3298.620481                    0.168471
# 2                     3167.716176                    0.109002
# 3                     4967.802504                    0.113148
# 4                     2702.966436                    0.061176
#
#    wavelet-LLL_ngtdm_Coarseness  wavelet-LLL_ngtdm_Complexity  \
# 0                      0.002030                   1733.014821
# 1                      0.002173                   1198.254380
# 2                      0.002366                   1716.921780
# 3                      0.002493                   1183.899751
# 4                      0.002091                   3721.568696
#
#    wavelet-LLL_ngtdm_Contrast  wavelet-LLL_ngtdm_Strength
# 0                    0.026899                    5.484464
# 1                    0.026713                    4.042621
# 2                    0.033027                    7.627719
# 3                    0.015043                    7.936936
# 4                    0.033197                   14.876286
#
# [5 rows x 1690 columns]

# %%
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3996 entries, 0 to 3995
# Columns: 1690 entries, dmp_pt_id to wavelet-LLL_ngtdm_Strength
# dtypes: float64(1688), int64(1), object(1)
# memory usage: 51.5+ MB

# %%
def process_clinical(df, selected_columns=None, correlation_threshold = 0.2, drop_na = True):
    object_float_columns = ["pack_years","halo_tumor_quality"]
    good_object_columns = ["histo","pdl1_tiss_site"]
    
    remove_columns = list(df.select_dtypes(include=['object']).columns)
    # if "dmp_pt_id" in remove_columns: remove_columns.append("dmp_pt_id")
    if "dmp_pt_id" in remove_columns: remove_columns.remove("dmp_pt_id")
    if "pdl1_image_id" in remove_columns: remove_columns.remove("pdl1_image_id")
    
    remove_columns.append("record_id")
    remove_columns.append("pfs_censor")
    # remove_columns.append("radiology_accession_number")
    remove_columns.append("os_int")
    remove_columns.append("bor")
    remove_columns.append("did_acc")
    remove_columns.append("sex")
    remove_columns.append("deid")
    remove_columns.append("label")
    remove_columns.append("clinical_pdl1_score") #removing because of empty cells in test data
    remove_columns.append("js_pdl1_score") #removing because of empty cells in test data
    
    for c in object_float_columns:
        remove_columns.remove(c)
        
    df = df.drop(columns=remove_columns)
    
    for c in object_float_columns:
        df[c] = pd.to_numeric(df[c], errors='coerce').astype(float)
    df["hist_adeno"] = df["hist_adeno"].astype(int)
    
    if selected_columns is None:
        correlations = df.drop(["dmp_pt_id" if "dmp_pt_id" in df.columns else "radiology_accession_number"], axis=1).iloc[:, :-1].corrwith(df['pfs'])
        selected_columns = correlations[(correlations >= correlation_threshold) | (correlations <= -correlation_threshold)].index
        selected_columns = list(selected_columns)
        if "dmp_pt_id" in df.columns: selected_columns.append("dmp_pt_id")
        if "radiology_accession_number" in df.columns: selected_columns.append("radiology_accession_number")
    
    if "dmp_pt_id" not in df.columns: 
        selected_columns.remove("dmp_pt_id")
        selected_columns.append("radiology_accession_number")
        
    for sc in selected_columns:
        if sc in ["dmp_pt_id", "radiology_accession_number","pfs"]: continue
        print(f"Correlation with {sc}: {df['pfs'].corr(df[sc])}")
    
    df = df[selected_columns]
    if drop_na: df = df.dropna().reset_index(drop=True)
    
    return df, selected_columns

# %%
df_clinical = pd.read_csv('/Users/gufran/Desktop/PfsPredictionLungCancer/clinical_data/clinical_data.csv').drop(["pdl1_image_id"], axis=1)
print(df_clinical.shape)

df_clinical_tr = df_clinical.drop(["radiology_accession_number"], axis=1)
df_clinical_te = df_clinical.drop(["dmp_pt_id"], axis=1)

df_clinical_tr, selected_columns = process_clinical(df_clinical_tr, correlation_threshold = 0.11)
df_clinical_te, _ = process_clinical(df_clinical_te, correlation_threshold = 0.11, selected_columns=selected_columns)
# Out:
# (366, 52)
# Correlation with albumin: 0.26071203044553243
# Correlation with dnlr: -0.11717087983081641
# Correlation with ecog: -0.1665222793734818
# Correlation with albumin: 0.26071203044553243
# Correlation with dnlr: -0.11717087983081641
# Correlation with ecog: -0.1665222793734818

# %%
df_t = pd.merge(df_t, df_clinical_tr, on='dmp_pt_id', how='inner')
df_v = pd.merge(df_v, df_clinical_te, on='radiology_accession_number', how='inner')

df_t.shape, df_v.shape
# Out:
# ((3996, 1694), (1176, 1694))

# %%
correlation_threshold = 0.1
correlations = df_t.drop("dmp_pt_id", axis=1).corrwith(df_t['pfs'])
selected_columns = correlations[(correlations >= correlation_threshold) | (correlations <= -correlation_threshold)].index

selected_columns = list(selected_columns)
# selected_columns.append("albumin")
# selected_columns.append("ecog")

# %%
for sc in selected_columns:
    if sc in ["dmp_pt_id", "pfs"]: continue
    print(f"Correlation with {sc}: {df_t['pfs'].corr(df_t[sc])}")
# Out:
# Correlation with original_firstorder_10Percentile: -0.16043499145721676
# Correlation with original_firstorder_90Percentile: -0.20932506044661645
# Correlation with original_firstorder_InterquartileRange: 0.10194727849112364
# Correlation with original_firstorder_Mean: -0.20189748064173424
# Correlation with original_firstorder_Median: -0.21681436649049524
# Correlation with original_firstorder_Minimum: -0.10321323734142564
# Correlation with original_firstorder_RootMeanSquared: 0.21326912797489453
# Correlation with original_glcm_ClusterTendency: 0.10816573011428601
# Correlation with original_glcm_Contrast: 0.11896090758668132
# Correlation with original_glcm_DifferenceAverage: 0.10069171276473073
# Correlation with original_glcm_InverseVariance: -0.13248411572515584
# Correlation with original_glcm_SumSquares: 0.11097330448510836
# Correlation with original_gldm_DependenceNonUniformityNormalized: 0.12216061095395497
# Correlation with original_ngtdm_Complexity: 0.13049139631450526
# Correlation with exponential_firstorder_Kurtosis: 0.2155898460870133
# Correlation with exponential_firstorder_Skewness: 0.19072659363671898
# Correlation with gradient_firstorder_10Percentile: 0.12143660688745195
# Correlation with gradient_firstorder_Energy: 0.11419154303351035
# Correlation with gradient_firstorder_TotalEnergy: 0.11419053659061634
# Correlation with gradient_glcm_Autocorrelation: 0.10867745679821653
# Correlation with gradient_gldm_LargeDependenceHighGrayLevelEmphasis: 0.1274578824677927
# Correlation with gradient_glszm_SizeZoneNonUniformity: 0.12607823843059443
# Correlation with lbp-3D-m1_glszm_SmallAreaEmphasis: -0.10103125603675042
# Correlation with lbp-3D-m1_glszm_SmallAreaHighGrayLevelEmphasis: -0.10105049509032053
# Correlation with lbp-3D-m1_glszm_SmallAreaLowGrayLevelEmphasis: -0.10095369478092431
# Correlation with lbp-3D-m2_firstorder_Entropy: -0.11332934114925787
# Correlation with lbp-3D-m2_firstorder_Maximum: -0.10595923152316813
# Correlation with lbp-3D-m2_firstorder_Uniformity: 0.11221843572603678
# Correlation with lbp-3D-m2_glcm_Autocorrelation: -0.11065969606031838
# Correlation with lbp-3D-m2_glcm_ClusterProminence: -0.11213344705781214
# Correlation with lbp-3D-m2_glcm_ClusterShade: -0.11148817222827866
# Correlation with lbp-3D-m2_glcm_ClusterTendency: -0.11086401976304597
# Correlation with lbp-3D-m2_glcm_Contrast: -0.11006732551796825
# Correlation with lbp-3D-m2_glcm_DifferenceAverage: -0.11006732551796825
# Correlation with lbp-3D-m2_glcm_DifferenceEntropy: -0.11173095254803442
# Correlation with lbp-3D-m2_glcm_DifferenceVariance: -0.11010210626039417
# Correlation with lbp-3D-m2_glcm_Id: 0.1100673255179715
# Correlation with lbp-3D-m2_glcm_Idm: 0.1100673255179715
# Correlation with lbp-3D-m2_glcm_Idmn: 0.11006732551799127
# Correlation with lbp-3D-m2_glcm_Idn: 0.11006732551797381
# Correlation with lbp-3D-m2_glcm_InverseVariance: -0.11006732551796825
# Correlation with lbp-3D-m2_glcm_JointAverage: -0.11047603746008185
# Correlation with lbp-3D-m2_glcm_JointEnergy: 0.11030461739335079
# Correlation with lbp-3D-m2_glcm_JointEntropy: -0.11183722137036531
# Correlation with lbp-3D-m2_glcm_MaximumProbability: 0.11027874610973061
# Correlation with lbp-3D-m2_glcm_SumAverage: -0.11047603746008149
# Correlation with lbp-3D-m2_glcm_SumEntropy: -0.11195551360711825
# Correlation with lbp-3D-m2_glcm_SumSquares: -0.11049301477802871
# Correlation with lbp-3D-m2_gldm_GrayLevelVariance: -0.11221843572603714
# Correlation with lbp-3D-m2_gldm_HighGrayLevelEmphasis: -0.11220287504508347
# Correlation with lbp-3D-m2_gldm_LowGrayLevelEmphasis: 0.11220287504508812
# Correlation with lbp-3D-m2_ngtdm_Complexity: -0.11291457080713964
# Correlation with lbp-3D-k_firstorder_10Percentile: -0.10779104417555237
# Correlation with lbp-3D-k_gldm_SmallDependenceEmphasis: -0.10780352201296539
# Correlation with lbp-3D-k_gldm_SmallDependenceHighGrayLevelEmphasis: -0.11665392306964695
# Correlation with lbp-3D-k_glszm_GrayLevelNonUniformityNormalized: -0.10870610933948181
# Correlation with lbp-3D-k_glszm_GrayLevelVariance: 0.10870610933948183
# Correlation with lbp-3D-k_glszm_SmallAreaEmphasis: -0.1471347361135375
# Correlation with lbp-3D-k_glszm_SmallAreaHighGrayLevelEmphasis: -0.14752537657815898
# Correlation with lbp-3D-k_glszm_SmallAreaLowGrayLevelEmphasis: -0.14415523650363107
# Correlation with logarithm_firstorder_90Percentile: -0.18548744438160697
# Correlation with logarithm_firstorder_Maximum: -0.1380590002321285
# Correlation with logarithm_firstorder_Mean: -0.13666703945093484
# Correlation with logarithm_firstorder_Median: -0.13838536451347636
# Correlation with logarithm_firstorder_Uniformity: 0.1037601583237504
# Correlation with logarithm_glcm_JointAverage: -0.10022196374510985
# Correlation with logarithm_glcm_JointEnergy: 0.11666304467215124
# Correlation with logarithm_glcm_MaximumProbability: 0.10399577833831912
# Correlation with logarithm_glcm_SumAverage: -0.1002219637451098
# Correlation with logarithm_gldm_LargeDependenceLowGrayLevelEmphasis: 0.12057140923600536
# Correlation with logarithm_gldm_LowGrayLevelEmphasis: 0.14552104188888634
# Correlation with logarithm_gldm_SmallDependenceHighGrayLevelEmphasis: -0.10430976530431953
# Correlation with logarithm_glrlm_LongRunLowGrayLevelEmphasis: 0.1286565495011688
# Correlation with logarithm_glrlm_LowGrayLevelRunEmphasis: 0.14710038537774622
# Correlation with logarithm_glrlm_ShortRunLowGrayLevelEmphasis: 0.1360950390394229
# Correlation with logarithm_glszm_LowGrayLevelZoneEmphasis: 0.12523966704297695
# Correlation with logarithm_glszm_SizeZoneNonUniformityNormalized: -0.1331516794885013
# Correlation with logarithm_glszm_SmallAreaEmphasis: -0.14166648510413324
# Correlation with square_firstorder_10Percentile: 0.19634912551818354
# Correlation with square_firstorder_90Percentile: 0.22734893533367617
# Correlation with square_firstorder_Entropy: 0.19566137902452987
# Correlation with square_firstorder_InterquartileRange: 0.22204176022429
# Correlation with square_firstorder_Maximum: 0.15911317827737104
# Correlation with square_firstorder_MeanAbsoluteDeviation: 0.19728136897266835
# Correlation with square_firstorder_Mean: 0.24975691607385633
# Correlation with square_firstorder_Median: 0.25389900841573837
# Correlation with square_firstorder_Minimum: 0.1345746526291031
# Correlation with square_firstorder_Range: 0.14870080973133015
# Correlation with square_firstorder_RobustMeanAbsoluteDeviation: 0.2118282161214536
# Correlation with square_firstorder_RootMeanSquared: 0.23912589792292274
# Correlation with square_firstorder_Uniformity: -0.17468629394426374
# Correlation with square_firstorder_Variance: 0.15203540158953904
# Correlation with square_glcm_Autocorrelation: 0.21552250691260405
# Correlation with square_glcm_ClusterTendency: 0.13167230861420043
# Correlation with square_glcm_Contrast: 0.23974617030402387
# Correlation with square_glcm_DifferenceAverage: 0.23056881543458288
# Correlation with square_glcm_DifferenceEntropy: 0.17947578602162237
# Correlation with square_glcm_DifferenceVariance: 0.2065185648013946
# Correlation with square_glcm_Id: -0.20097191896614586
# Correlation with square_glcm_Idm: -0.20171204800506026
# Correlation with square_glcm_Idmn: -0.13763260845723457
# Correlation with square_glcm_Idn: -0.17094357147857783
# Correlation with square_glcm_Imc2: 0.13276055429587372
# Correlation with square_glcm_InverseVariance: 0.13464837698657658
# Correlation with square_glcm_JointAverage: 0.25571890013504284
# Correlation with square_glcm_JointEnergy: -0.17081536483077245
# Correlation with square_glcm_JointEntropy: 0.2062881200451401
# Correlation with square_glcm_MaximumProbability: -0.192941368743382
# Correlation with square_glcm_SumAverage: 0.2557189001350427
# Correlation with square_glcm_SumEntropy: 0.19929942125168498
# Correlation with square_glcm_SumSquares: 0.14085279333002218
# Correlation with square_gldm_DependenceEntropy: 0.12661751501812063
# Correlation with square_gldm_GrayLevelVariance: 0.15231902527431332
# Correlation with square_gldm_HighGrayLevelEmphasis: 0.23664891620948944
# Correlation with square_gldm_LargeDependenceEmphasis: -0.14262600391822822
# Correlation with square_gldm_LargeDependenceHighGrayLevelEmphasis: 0.12052311795791915
# Correlation with square_gldm_LargeDependenceLowGrayLevelEmphasis: -0.1529016960981376
# Correlation with square_gldm_LowGrayLevelEmphasis: -0.20693186477992515
# Correlation with square_gldm_SmallDependenceEmphasis: 0.20426701800023275
# Correlation with square_gldm_SmallDependenceHighGrayLevelEmphasis: 0.25921698076115796
# Correlation with square_glrlm_GrayLevelNonUniformityNormalized: -0.11209587941531805
# Correlation with square_glrlm_GrayLevelVariance: 0.1481103521276228
# Correlation with square_glrlm_HighGrayLevelRunEmphasis: 0.23192120740447525
# Correlation with square_glrlm_LowGrayLevelRunEmphasis: -0.15434140598280574
# Correlation with square_glrlm_RunLengthNonUniformityNormalized: 0.16344711592883548
# Correlation with square_glrlm_RunPercentage: 0.161165166402892
# Correlation with square_glrlm_ShortRunEmphasis: 0.13423142024391735
# Correlation with square_glrlm_ShortRunHighGrayLevelEmphasis: 0.23385508602132635
# Correlation with square_glszm_GrayLevelVariance: 0.15068490290039424
# Correlation with square_glszm_HighGrayLevelZoneEmphasis: 0.21135375884839258
# Correlation with square_glszm_SizeZoneNonUniformity: 0.14503360654908576
# Correlation with square_glszm_SmallAreaHighGrayLevelEmphasis: 0.20590079759657573
# Correlation with square_glszm_ZonePercentage: 0.20552618222386848
# Correlation with square_ngtdm_Complexity: 0.24673724247503448
# Correlation with square_ngtdm_Contrast: 0.20033724754097118
# Correlation with squareroot_firstorder_90Percentile: -0.19967811458943616
# Correlation with squareroot_firstorder_Maximum: -0.11553927452431272
# Correlation with squareroot_firstorder_Mean: -0.16156700239136537
# Correlation with squareroot_firstorder_Median: -0.16985932282292138
# Correlation with squareroot_firstorder_RootMeanSquared: 0.18053354377255215
# Correlation with wavelet-LHL_firstorder_90Percentile: 0.16696888776671717
# Correlation with wavelet-LHL_firstorder_Energy: 0.11360040274382603
# Correlation with wavelet-LHL_firstorder_TotalEnergy: 0.11357762309003246
# Correlation with wavelet-LHL_firstorder_Variance: 0.10665045830031848
# Correlation with wavelet-LHL_glcm_ClusterTendency: 0.11727932937800988
# Correlation with wavelet-LHL_glcm_Contrast: 0.10637883301055359
# Correlation with wavelet-LHL_glcm_SumSquares: 0.11634106369567024
# Correlation with wavelet-LHL_gldm_DependenceNonUniformityNormalized: 0.10626539175829573
# Correlation with wavelet-LHL_gldm_DependenceVariance: -0.1055189029655945
# Correlation with wavelet-LHL_gldm_GrayLevelVariance: 0.1084390332091432
# Correlation with wavelet-LHL_ngtdm_Contrast: 0.11068226814069061
# Correlation with wavelet-HLL_firstorder_90Percentile: 0.1342472083095371
# Correlation with wavelet-HLL_firstorder_Energy: 0.14319062562148216
# Correlation with wavelet-HLL_firstorder_InterquartileRange: 0.10680812064343556
# Correlation with wavelet-HLL_firstorder_Maximum: 0.12505730154801026
# Correlation with wavelet-HLL_firstorder_MeanAbsoluteDeviation: 0.10556980156754996
# Correlation with wavelet-HLL_firstorder_Range: 0.10346461269826636
# Correlation with wavelet-HLL_firstorder_RobustMeanAbsoluteDeviation: 0.10274938622777637
# Correlation with wavelet-HLL_firstorder_RootMeanSquared: 0.10153592075888226
# Correlation with wavelet-HLL_firstorder_TotalEnergy: 0.14318456431104032
# Correlation with wavelet-HLL_firstorder_Variance: 0.12395786310601918
# Correlation with wavelet-HLL_glcm_ClusterTendency: 0.12766371241130978
# Correlation with wavelet-HLL_glcm_Contrast: 0.13518982376375333
# Correlation with wavelet-HLL_glcm_DifferenceAverage: 0.13004062511074616
# Correlation with wavelet-HLL_glcm_DifferenceEntropy: 0.10692853908439146
# Correlation with wavelet-HLL_glcm_DifferenceVariance: 0.12737995863797852
# Correlation with wavelet-HLL_glcm_Id: -0.10127678057842808
# Correlation with wavelet-HLL_glcm_Idm: -0.10234290324133251
# Correlation with wavelet-HLL_glcm_SumSquares: 0.13197825069841473
# Correlation with wavelet-HLL_gldm_DependenceNonUniformityNormalized: 0.10324522568730315
# Correlation with wavelet-HLL_gldm_GrayLevelVariance: 0.12473683519489817
# Correlation with wavelet-HLL_gldm_SmallDependenceHighGrayLevelEmphasis: 0.11635016830040534
# Correlation with wavelet-HLL_glrlm_GrayLevelVariance: 0.12029964236297992
# Correlation with wavelet-HLL_glszm_GrayLevelVariance: 0.10217398401160656
# Correlation with wavelet-HLL_glszm_SizeZoneNonUniformity: 0.11968881429610241
# Correlation with wavelet-HLL_ngtdm_Complexity: 0.1464687538453856
# Correlation with wavelet-HHL_firstorder_Uniformity: -0.10195115961519799
# Correlation with wavelet-HHL_glcm_Autocorrelation: 0.10206182610532882
# Correlation with wavelet-HHL_glcm_JointEnergy: -0.10631840578811054
# Correlation with wavelet-HHL_glcm_JointEntropy: 0.10095129041826767
# Correlation with wavelet-HHL_glcm_SumEntropy: 0.10539546110036228
# Correlation with wavelet-HHL_gldm_HighGrayLevelEmphasis: 0.10232626147479192
# Correlation with wavelet-HHL_gldm_LargeDependenceHighGrayLevelEmphasis: 0.10142136240714782
# Correlation with wavelet-HHL_glrlm_HighGrayLevelRunEmphasis: 0.10247081957630372
# Correlation with wavelet-HHL_glrlm_LongRunHighGrayLevelEmphasis: 0.10501076136863186
# Correlation with wavelet-HHL_glrlm_ShortRunHighGrayLevelEmphasis: 0.10187626522285492
# Correlation with wavelet-LLL_firstorder_10Percentile: -0.15875432614394258
# Correlation with wavelet-LLL_firstorder_90Percentile: -0.20784644281199333
# Correlation with wavelet-LLL_firstorder_Mean: -0.20032737680091353
# Correlation with wavelet-LLL_firstorder_Median: -0.2146736645933141
# Correlation with wavelet-LLL_firstorder_Minimum: -0.10552460621445334
# Correlation with wavelet-LLL_firstorder_RootMeanSquared: 0.211723526382022
# Correlation with wavelet-LLL_glcm_ClusterTendency: 0.10576396776882303
# Correlation with wavelet-LLL_glcm_Contrast: 0.11105462287493811
# Correlation with wavelet-LLL_glcm_SumSquares: 0.10797843510850239
# Correlation with wavelet-LLL_ngtdm_Complexity: 0.13802212125425734
# Correlation with albumin: 0.29776446107636984
# Correlation with dnlr: -0.15080521275251876
# Correlation with ecog: -0.11416395202250551

# %%
df_v
# Out:
#      radiology_accession_number  lesion_index  original_shape_Elongation  \
# 0                        190310             1                   0.773650
# 1                        190310             1                   0.759573
# 2                        190310             1                   0.792993
# 3                        190310             1                   0.754851
# 4                        190310             1                   0.737045
# ...                         ...           ...                        ...
# 1171                     191182             2                   0.337839
# 1172                     191182             2                   0.378958
# 1173                     191182             2                   0.345684
# 1174                     191182             2                   0.341878
# 1175                     191182             2                   0.367517
#
#       original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                    0.497674                        7.566988
# 1                    0.487954                        7.103445
# 2                    0.468580                        5.898571
# 3                    0.549451                        7.673298
# 4                    0.463315                        7.322990
# ...                       ...                             ...
# 1171                 0.307031                        9.498734
# 1172                 0.300726                        8.273343
# 1173                 0.274051                        8.166433
# 1174                 0.295010                        9.663671
# 1175                 0.299179                        9.658288
#
#       original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                          15.204695                               14.560220
# 1                          14.557626                               13.601471
# 2                          12.588187                               13.152946
# 3                          13.965401                               14.035669
# 4                          15.805635                               13.152946
# ...                              ...                                     ...
# 1171                       30.937349                               27.459060
# 1172                       27.511229                               26.172505
# 1173                       29.798920                               26.400758
# 1174                       32.757136                               29.154759
# 1175                       32.282671                               31.256999
#
#       original_shape_Maximum2DDiameterRow  \
# 0                               15.811388
# 1                               15.000000
# 2                               12.083046
# 3                               15.000000
# 4                               21.400935
# ...                                   ...
# 1171                            33.241540
# 1172                            29.120440
# 1173                            29.732137
# 1174                            32.572995
# 1175                            34.785054
#
#       original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 0                                 14.866069                         17.000000
# 1                                 14.560220                         16.552945
# 2                                 13.601471                         14.628739
# 3                                 14.866069                         17.117243
# 4                                 15.811388                         21.494185
# ...                                     ...                               ...
# 1171                              13.928388                         33.376639
# 1172                              14.212670                         29.189039
# 1173                              13.892444                         34.205263
# 1174                              14.560220                         35.958309
# 1175                              14.560220                         34.799425
#
#       ...  wavelet-LLL_glszm_ZoneVariance  wavelet-LLL_ngtdm_Busyness  \
# 0     ...                        1.957267                    0.005179
# 1     ...                        1.731737                    0.007126
# 2     ...                        0.955822                    0.008503
# 3     ...                        0.731963                    0.015744
# 4     ...                        0.758003                    0.012408
# ...   ...                             ...                         ...
# 1171  ...                       24.889789                    0.034983
# 1172  ...                       38.865663                    0.032658
# 1173  ...                       35.637054                    0.053079
# 1174  ...                       22.855035                    0.020794
# 1175  ...                       19.255637                    0.019136
#
#       wavelet-LLL_ngtdm_Coarseness  wavelet-LLL_ngtdm_Complexity  \
# 0                         0.018377                  27138.212449
# 1                         0.020969                  16761.257501
# 2                         0.026378                  11716.812512
# 3                         0.018415                  15458.951270
# 4                         0.018273                  13859.448289
# ...                            ...                           ...
# 1171                      0.006381                   7593.595023
# 1172                      0.007893                   4886.665975
# 1173                      0.007211                   3238.598946
# 1174                      0.005950                  11931.027675
# 1175                      0.005912                  16541.806291
#
#       wavelet-LLL_ngtdm_Contrast  wavelet-LLL_ngtdm_Strength  albumin  dnlr  \
# 0                       0.718451                   89.793935      3.9   2.5
# 1                       0.616416                   71.385709      3.9   2.5
# 2                       0.602118                   63.227113      3.9   2.5
# 3                       0.791238                   44.017116      3.9   2.5
# 4                       0.660879                   45.112721      3.9   2.5
# ...                          ...                         ...      ...   ...
# 1171                    0.346688                   14.225450      3.8   3.0
# 1172                    0.162361                   17.558279      3.8   3.0
# 1173                    0.169399                    9.309697      3.8   3.0
# 1174                    0.236597                   24.237781      3.8   3.0
# 1175                    0.361478                   26.210097      3.8   3.0
#
#        pfs  ecog
# 0     26.1     1
# 1     26.1     1
# 2     26.1     1
# 3     26.1     1
# 4     26.1     1
# ...    ...   ...
# 1171   2.1     1
# 1172   2.1     1
# 1173   2.1     1
# 1174   2.1     1
# 1175   2.1     1
#
# [1176 rows x 1694 columns]

# %%
df_t_t = df_t.groupby('dmp_pt_id').transform('mean')

# %%
df_t
# Out:
#       dmp_pt_id  lesion_index  original_shape_Elongation  \
# 0     P-0000239             1                   0.609991
# 1     P-0000239             1                   0.602659
# 2     P-0000239             1                   0.626577
# 3     P-0000239             1                   0.685398
# 4     P-0000239             1                   0.633165
# ...         ...           ...                        ...
# 3991  P-0045298             2                   0.583836
# 3992  P-0045298             2                   0.544379
# 3993  P-0045298             2                   0.533278
# 3994  P-0045298             2                   0.469694
# 3995  P-0045298             2                   0.537748
#
#       original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                    0.547450                       17.435125
# 1                    0.557320                       17.530776
# 2                    0.535450                       17.343918
# 3                    0.640327                       18.342757
# 4                    0.559689                       17.613374
# ...                       ...                             ...
# 3991                 0.428494                       15.704461
# 3992                 0.369077                       14.453937
# 3993                 0.378726                       14.931061
# 3994                 0.395143                       14.388747
# 3995                 0.359847                       14.540323
#
#       original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                          31.847914                               33.970576
# 1                          31.455496                               32.557641
# 2                          32.391268                               37.802116
# 3                          28.645906                               34.132096
# 4                          31.469915                               34.132096
# ...                              ...                                     ...
# 3991                       36.650325                               41.194660
# 3992                       39.162403                               41.484937
# 3993                       39.424493                               48.507731
# 3994                       36.414023                               30.594117
# 3995                       40.406910                               48.083261
#
#       original_shape_Maximum2DDiameterRow  \
# 0                               33.105891
# 1                               32.695565
# 2                               38.897301
# 3                               38.897301
# 4                               38.897301
# ...                                   ...
# 3991                            41.194660
# 3992                            41.194660
# 3993                            42.190046
# 3994                            34.481879
# 3995                            41.593269
#
#       original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 0                                 25.553865                         39.962482
# 1                                 24.351591                         39.089641
# 2                                 26.400758                         41.448764
# 3                                 28.844410                         39.344631
# 4                                 28.844410                         39.344631
# ...                                     ...                               ...
# 3991                              22.472205                         41.388404
# 3992                              22.472205                         43.139309
# 3993                              21.377558                         48.672374
# 3994                              22.472205                         34.568772
# 3995                              22.360680                         48.548944
#
#       ...  wavelet-LLL_glszm_ZoneVariance  wavelet-LLL_ngtdm_Busyness  \
# 0     ...                     3270.745421                    0.128236
# 1     ...                     3298.620481                    0.168471
# 2     ...                     3167.716176                    0.109002
# 3     ...                     4967.802504                    0.113148
# 4     ...                     2702.966436                    0.061176
# ...   ...                             ...                         ...
# 3991  ...                      104.797049                    0.059051
# 3992  ...                      117.055375                    0.060956
# 3993  ...                      109.117767                    0.068820
# 3994  ...                      148.695555                    0.071491
# 3995  ...                      111.807815                    0.045360
#
#       wavelet-LLL_ngtdm_Coarseness  wavelet-LLL_ngtdm_Complexity  \
# 0                         0.002030                   1733.014821
# 1                         0.002173                   1198.254380
# 2                         0.002366                   1716.921780
# 3                         0.002493                   1183.899751
# 4                         0.002091                   3721.568696
# ...                            ...                           ...
# 3991                      0.003033                   5575.262403
# 3992                      0.003595                   4538.097910
# 3993                      0.003392                   4286.083430
# 3994                      0.003768                   3146.302617
# 3995                      0.003593                   5119.086477
#
#       wavelet-LLL_ngtdm_Contrast  wavelet-LLL_ngtdm_Strength  albumin  dnlr  \
# 0                       0.026899                    5.484464      3.0   3.3
# 1                       0.026713                    4.042621      3.0   3.3
# 2                       0.033027                    7.627719      3.0   3.3
# 3                       0.015043                    7.936936      3.0   3.3
# 4                       0.033197                   14.876286      3.0   3.3
# ...                          ...                         ...      ...   ...
# 3991                    0.128496                    8.680779      3.6   1.9
# 3992                    0.126464                    9.049781      3.6   1.9
# 3993                    0.139613                    7.730850      3.6   1.9
# 3994                    0.083086                    8.653283      3.6   1.9
# 3995                    0.142258                   10.763797      3.6   1.9
#
#        pfs  ecog
# 0      1.8     1
# 1      1.8     1
# 2      1.8     1
# 3      1.8     1
# 4      1.8     1
# ...    ...   ...
# 3991  12.7     1
# 3992  12.7     1
# 3993  12.7     1
# 3994  12.7     1
# 3995  12.7     1
#
# [3996 rows x 1694 columns]

# %%
df_t_t
# Out:
#       lesion_index  original_shape_Elongation  original_shape_Flatness  \
# 0              1.0                   0.636928                 0.576307
# 1              1.0                   0.636928                 0.576307
# 2              1.0                   0.636928                 0.576307
# 3              1.0                   0.636928                 0.576307
# 4              1.0                   0.636928                 0.576307
# ...            ...                        ...                      ...
# 3991           1.5                   0.605400                 0.443065
# 3992           1.5                   0.605400                 0.443065
# 3993           1.5                   0.605400                 0.443065
# 3994           1.5                   0.605400                 0.443065
# 3995           1.5                   0.605400                 0.443065
#
#       original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                          17.894897                        31.14779
# 1                          17.894897                        31.14779
# 2                          17.894897                        31.14779
# 3                          17.894897                        31.14779
# 4                          17.894897                        31.14779
# ...                              ...                             ...
# 3991                       10.427869                        25.43526
# 3992                       10.427869                        25.43526
# 3993                       10.427869                        25.43526
# 3994                       10.427869                        25.43526
# 3995                       10.427869                        25.43526
#
#       original_shape_Maximum2DDiameterColumn  \
# 0                                  34.914166
# 1                                  34.914166
# 2                                  34.914166
# 3                                  34.914166
# 4                                  34.914166
# ...                                      ...
# 3991                               26.849856
# 3992                               26.849856
# 3993                               26.849856
# 3994                               26.849856
# 3995                               26.849856
#
#       original_shape_Maximum2DDiameterRow  \
# 0                               37.039286
# 1                               37.039286
# 2                               37.039286
# 3                               37.039286
# 4                               37.039286
# ...                                   ...
# 3991                            25.489469
# 3992                            25.489469
# 3993                            25.489469
# 3994                            25.489469
# 3995                            25.489469
#
#       original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 0                                 27.732208                         40.358926
# 1                                 27.732208                         40.358926
# 2                                 27.732208                         40.358926
# 3                                 27.732208                         40.358926
# 4                                 27.732208                         40.358926
# ...                                     ...                               ...
# 3991                              17.146605                         28.450097
# 3992                              17.146605                         28.450097
# 3993                              17.146605                         28.450097
# 3994                              17.146605                         28.450097
# 3995                              17.146605                         28.450097
#
#       original_shape_MeshVolume  ...  wavelet-LLL_glszm_ZoneVariance  \
# 0                   6936.281250  ...                     3179.635533
# 1                   6936.281250  ...                     3179.635533
# 2                   6936.281250  ...                     3179.635533
# 3                   6936.281250  ...                     3179.635533
# 4                   6936.281250  ...                     3179.635533
# ...                         ...  ...                             ...
# 3991                2509.326389  ...                       61.235191
# 3992                2509.326389  ...                       61.235191
# 3993                2509.326389  ...                       61.235191
# 3994                2509.326389  ...                       61.235191
# 3995                2509.326389  ...                       61.235191
#
#       wavelet-LLL_ngtdm_Busyness  wavelet-LLL_ngtdm_Coarseness  \
# 0                       0.090819                      0.002223
# 1                       0.090819                      0.002223
# 2                       0.090819                      0.002223
# 3                       0.090819                      0.002223
# 4                       0.090819                      0.002223
# ...                          ...                           ...
# 3991                    0.041559                      0.017948
# 3992                    0.041559                      0.017948
# 3993                    0.041559                      0.017948
# 3994                    0.041559                      0.017948
# 3995                    0.041559                      0.017948
#
#       wavelet-LLL_ngtdm_Complexity  wavelet-LLL_ngtdm_Contrast  \
# 0                      2760.583802                    0.029861
# 1                      2760.583802                    0.029861
# 2                      2760.583802                    0.029861
# 3                      2760.583802                    0.029861
# 4                      2760.583802                    0.029861
# ...                            ...                         ...
# 3991                   3129.611258                    0.170314
# 3992                   3129.611258                    0.170314
# 3993                   3129.611258                    0.170314
# 3994                   3129.611258                    0.170314
# 3995                   3129.611258                    0.170314
#
#       wavelet-LLL_ngtdm_Strength  albumin  dnlr   pfs  ecog
# 0                      12.090630      3.0   3.3   1.8   1.0
# 1                      12.090630      3.0   3.3   1.8   1.0
# 2                      12.090630      3.0   3.3   1.8   1.0
# 3                      12.090630      3.0   3.3   1.8   1.0
# 4                      12.090630      3.0   3.3   1.8   1.0
# ...                          ...      ...   ...   ...   ...
# 3991                   19.719824      3.6   1.9  12.7   1.0
# 3992                   19.719824      3.6   1.9  12.7   1.0
# 3993                   19.719824      3.6   1.9  12.7   1.0
# 3994                   19.719824      3.6   1.9  12.7   1.0
# 3995                   19.719824      3.6   1.9  12.7   1.0
#
# [3996 rows x 1693 columns]

# %%
# df_t.drop(["dmp_pt_id"], axis=1, inplace=True)
# df_v.drop(["radiology_accession_number"], axis=1, inplace=True)

df_t = df_t[selected_columns]
df_v = df_v[selected_columns]

# %%
X_train, y_train = df_t.drop(["pfs"], axis=1), df_t["pfs"]
X_test, y_test = df_v.drop(["pfs"], axis=1), df_v["pfs"]

# %%
X_test
# Out:
#       original_firstorder_10Percentile  original_firstorder_90Percentile  \
# 0                               -336.5                              80.0
# 1                               -296.0                              72.0
# 2                               -286.5                              52.0
# 3                               -367.0                              36.8
# 4                               -323.0                              44.0
# ...                                ...                               ...
# 1171                            -234.9                              11.0
# 1172                            -124.0                              17.0
# 1173                            -119.0                              16.0
# 1174                            -203.6                              10.0
# 1175                            -300.4                               8.0
#
#       original_firstorder_InterquartileRange  original_firstorder_Mean  \
# 0                                     232.50                -97.708696
# 1                                     211.00                -96.332293
# 2                                     172.50                -89.674528
# 3                                     249.00               -158.234399
# 4                                     221.50               -120.083578
# ...                                      ...                       ...
# 1171                                  108.25                -79.152778
# 1172                                   69.00                -45.135057
# 1173                                   72.00                -45.069490
# 1174                                  111.50                -80.642680
# 1175                                  156.00               -110.815754
#
#       original_firstorder_Median  original_firstorder_Minimum  \
# 0                          -55.0                       -754.0
# 1                          -72.0                       -618.0
# 2                          -65.5                       -521.0
# 3                         -145.0                       -521.0
# 4                         -100.5                       -521.0
# ...                          ...                          ...
# 1171                       -47.0                       -454.0
# 1172                       -28.0                       -374.0
# 1173                       -33.0                       -361.0
# 1174                       -54.0                       -655.0
# 1175                       -69.0                       -655.0
#
#       original_firstorder_RootMeanSquared  original_glcm_ClusterTendency  \
# 0                              196.446405                     192.102618
# 1                              175.732206                     152.443723
# 2                              155.540188                     118.043977
# 3                              218.496377                     167.143370
# 4                              185.142368                     145.606646
# ...                                   ...                            ...
# 1171                           125.592702                      64.099839
# 1172                            80.888946                      29.370230
# 1173                            73.194464                      21.599795
# 1174                           124.662078                      62.205736
# 1175                           167.694029                     112.302379
#
#       original_glcm_Contrast  original_glcm_DifferenceAverage  ...  \
# 0                  33.959419                         4.078717  ...
# 1                  23.305124                         3.564688  ...
# 2                  19.792805                         3.464408  ...
# 3                  29.902218                         4.237533  ...
# 4                  26.090809                         3.915008  ...
# ...                      ...                              ...  ...
# 1171               12.536466                         2.369677  ...
# 1172                6.305726                         1.672006  ...
# 1173                5.478303                         1.619794  ...
# 1174               12.172869                         2.357429  ...
# 1175               17.732292                         2.864750  ...
#
#       wavelet-LLL_firstorder_Median  wavelet-LLL_firstorder_Minimum  \
# 0                       -184.746411                    -2101.085613
# 1                       -216.053009                    -1751.408325
# 2                       -190.663567                    -1463.076294
# 3                       -430.964600                    -1463.076294
# 4                       -297.833115                    -1463.076294
# ...                             ...                             ...
# 1171                    -136.525055                    -1240.312500
# 1172                     -79.855190                    -1075.861816
# 1173                     -93.494545                     -999.430786
# 1174                    -156.578415                    -1821.798584
# 1175                    -201.369247                    -1821.798584
#
#       wavelet-LLL_firstorder_RootMeanSquared  \
# 0                                 561.711338
# 1                                 503.862395
# 2                                 442.451877
# 3                                 621.569105
# 4                                 526.362145
# ...                                      ...
# 1171                              358.640738
# 1172                              231.706467
# 1173                              209.039023
# 1174                              352.787842
# 1175                              477.032969
#
#       wavelet-LLL_glcm_ClusterTendency  wavelet-LLL_glcm_Contrast  \
# 0                          1563.901199                 243.749234
# 1                          1244.464875                 179.356835
# 2                           935.666670                 154.331332
# 3                          1323.460052                 222.361430
# 4                          1155.754413                 193.101254
# ...                                ...                        ...
# 1171                        523.660995                  96.179783
# 1172                        240.814694                  49.008330
# 1173                        176.409223                  41.999565
# 1174                        492.887134                  91.695847
# 1175                        906.125638                 134.362414
#
#       wavelet-LLL_glcm_SumSquares  wavelet-LLL_ngtdm_Complexity  albumin  \
# 0                      451.912608                  27138.212449      3.9
# 1                      355.955428                  16761.257501      3.9
# 2                      272.499500                  11716.812512      3.9
# 3                      386.455370                  15458.951270      3.9
# 4                      337.213917                  13859.448289      3.9
# ...                           ...                           ...      ...
# 1171                   154.960194                   7593.595023      3.8
# 1172                    72.455756                   4886.665975      3.8
# 1173                    54.602197                   3238.598946      3.8
# 1174                   146.145745                  11931.027675      3.8
# 1175                   260.122013                  16541.806291      3.8
#
#       dnlr  ecog
# 0      2.5     1
# 1      2.5     1
# 2      2.5     1
# 3      2.5     1
# 4      2.5     1
# ...    ...   ...
# 1171   3.0     1
# 1172   3.0     1
# 1173   3.0     1
# 1174   3.0     1
# 1175   3.0     1
#
# [1176 rows x 199 columns]

# %%
classifiers_reg = {
    # 'SVM': {
    #     'name': 'Support Vector Machine',
    #     'classifier': SVR(),
    #     'param_grid': {'C': [0.1, 1.0, 10.0], 'kernel': ['linear', 'rbf']}
    # },
    'XGBoost': {
        'name': 'XGBoost',
        'classifier': XGBRegressor(),
        'param_grid': {'n_estimators': [50, 100, 200], 'max_depth': [3, 4, 5]}
    },
    'AdaBoost': {
        'name': 'AdaBoost',
        'classifier': AdaBoostRegressor(),
        'param_grid': {'n_estimators': [50, 100, 200], 'learning_rate': [0.1, 0.5, 1.0]}
    },
    'RandomForest': {
        'name': 'Random Forest',
        'classifier': RandomForestRegressor(),
        'param_grid': {'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20]}
    },
    'DecisionTree': {
        'name': 'Decision Tree',
        'classifier': DecisionTreeRegressor(),
        'param_grid': {'max_depth': [None, 10, 20]}
    }
}

# %%
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr

best_models = {}

for clf_name, clf_info in classifiers_reg.items():
    print(f"Performing GridSearchCV for {clf_info['name']}...")
    
    clf = clf_info['classifier']
    param_grid = clf_info['param_grid']
    
    grid_search = GridSearchCV(clf, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    best_models[clf_name] = grid_search.best_estimator_

print()

for clf_name, best_model in best_models.items():
    print(f"Evaluating {clf_name} on test data...")
    
    y_pred = best_model.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    pearson_coefficient, _ = pearsonr(y_test, y_pred)
    
    print(f"Mean Squared Error on Test Data: {mse:.4f}")
    print(f"Pearson Correlation Coefficient on Test Data: {pearson_coefficient:.4f}\n")
# Out:
# Performing GridSearchCV for XGBoost...
# Performing GridSearchCV for AdaBoost...
# Performing GridSearchCV for Random Forest...
# Performing GridSearchCV for Decision Tree...
#
# Evaluating XGBoost on test data...
# Mean Squared Error on Test Data: 172.3040
# Pearson Correlation Coefficient on Test Data: 0.0246
#
# Evaluating AdaBoost on test data...
# Mean Squared Error on Test Data: 143.6442
# Pearson Correlation Coefficient on Test Data: 0.2945
#
# Evaluating RandomForest on test data...
# Mean Squared Error on Test Data: 145.8118
# Pearson Correlation Coefficient on Test Data: 0.2644
#
# Evaluating DecisionTree on test data...
# Mean Squared Error on Test Data: 170.9679
# Pearson Correlation Coefficient on Test Data: 0.1767
